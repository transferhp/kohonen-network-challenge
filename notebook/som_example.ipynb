# %%
import sys
import os
import matplotlib.pyplot as plt

# %%
# import module from another directory temorarily
# Note: This can be replaced by packaging the module that contains our script,
# then we can pip install *.whl file to have full denpencies anywhere as we run the notebook.
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"/kohonen-challenge")

# %%
from kohonen_challenge import SOM

# %%
import numpy as np

# %%
np.random.seed(1234)
input_data = np.random.random((20,3))
input_data
# Out:
# array([[0.19151945, 0.62210877, 0.43772774],
#        [0.78535858, 0.77997581, 0.27259261],
#        [0.27646426, 0.80187218, 0.95813935],
#        [0.87593263, 0.35781727, 0.50099513],
#        [0.68346294, 0.71270203, 0.37025075],
#        [0.56119619, 0.50308317, 0.01376845],
#        [0.77282662, 0.88264119, 0.36488598],
#        [0.61539618, 0.07538124, 0.36882401],
#        [0.9331401 , 0.65137814, 0.39720258],
#        [0.78873014, 0.31683612, 0.56809865],
#        [0.86912739, 0.43617342, 0.80214764],
#        [0.14376682, 0.70426097, 0.70458131],
#        [0.21879211, 0.92486763, 0.44214076],
#        [0.90931596, 0.05980922, 0.18428708],
#        [0.04735528, 0.67488094, 0.59462478],
#        [0.53331016, 0.04332406, 0.56143308],
#        [0.32966845, 0.50296683, 0.11189432],
#        [0.60719371, 0.56594464, 0.00676406],
#        [0.61744171, 0.91212289, 0.79052413],
#        [0.99208147, 0.95880176, 0.79196414]])

# %%
som = SOM(10,10, 500)

# %%
som.fit(input_data)
# Out:
# Epoch=0, BMU_idx=[1, 9], radius=5.0, learning_rate=0.1
# Epoch=1, BMU_idx=[8, 4], radius=4.999967746839249, learning_rate=0.09999935493678498
# Epoch=2, BMU_idx=[0, 6], radius=4.999935493886551, learning_rate=0.09999870987773102
# Epoch=3, BMU_idx=[0, 5], radius=4.999903241141904, learning_rate=0.0999980648228381
# Epoch=4, BMU_idx=[5, 1], radius=4.999870988605309, learning_rate=0.09999741977210619
# Epoch=5, BMU_idx=[8, 4], radius=4.999838736276764, learning_rate=0.09999677472553528
# Epoch=6, BMU_idx=[8, 4], radius=4.999806484156266, learning_rate=0.09999612968312532
# Epoch=7, BMU_idx=[0, 6], radius=4.999774232243814, learning_rate=0.09999548464487629
# Epoch=8, BMU_idx=[2, 8], radius=4.999741980539407, learning_rate=0.09999483961078814
# Epoch=9, BMU_idx=[0, 1], radius=4.999709729043045, learning_rate=0.0999941945808609
# Epoch=10, BMU_idx=[2, 8], radius=4.999677477754725, learning_rate=0.0999935495550945
# ...

# %%
image_data = som.get_map
plt.imshow(image_data)

# %%
# %time som.fit(input_data)
# Out:
# Epoch=0, BMU_idx=[0, 0], radius=5.0, learning_rate=0.1
# Epoch=1, BMU_idx=[0, 9], radius=4.999967746839249, learning_rate=0.09999935493678498
# Epoch=2, BMU_idx=[0, 0], radius=4.999935493886551, learning_rate=0.09999870987773102
# Epoch=3, BMU_idx=[0, 5], radius=4.999903241141904, learning_rate=0.0999980648228381
# Epoch=4, BMU_idx=[0, 5], radius=4.999870988605309, learning_rate=0.09999741977210619
# Epoch=5, BMU_idx=[9, 5], radius=4.999838736276764, learning_rate=0.09999677472553528
# Epoch=6, BMU_idx=[0, 9], radius=4.999806484156266, learning_rate=0.09999612968312532
# Epoch=7, BMU_idx=[0, 9], radius=4.999774232243814, learning_rate=0.09999548464487629
# Epoch=8, BMU_idx=[0, 0], radius=4.999741980539407, learning_rate=0.09999483961078814
# Epoch=9, BMU_idx=[9, 0], radius=4.999709729043045, learning_rate=0.0999941945808609
# Epoch=10, BMU_idx=[6, 0], radius=4.999677477754725, learning_rate=0.0999935495550945
# ...
